# %%
import numpy as np
import matplotlib.pyplot as plt
import Sk
from tqdm import tqdm

from WLM import WLChain

# %%
q = (np.logspace(0,4,65))

q
L = 1
b = L/100

N_backbone = 10000
a_backbone = N_backbone/100
lambda_backbone = 1/N_backbone

# Pedersen_1996
S_q = Sk.Sk(q,L,b)

# MC
chain01 = WLChain(N_backbone,a_backbone,lambda_backbone)
chain01.d_exc = chain01.a*0.1
chain01.apply_SA = 1

def sample_S_q(n_sample,chain_func,p):
    S_q = np.zeros_like(q)
    for i in tqdm(range(n_sample)):
        chain_func.chain()
        chain_func.scatter_direct(q,n_merge=1,p_sub=p)
        S_q += chain_func.S_q
        
    return(S_q)

n_sample = 50
S_q_sample = sample_S_q(n_sample,chain01,0.025)
S_q_MC = S_q_sample/n_sample
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 50/50 [01:30<00:00,  1.80s/it]

# %%
plt.close('all')
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot()
ax.plot(q,S_q,'-k')
ax.plot(q,S_q_MC,'-r')
ax.set_xscale('log')
ax.set_yscale('log')

plt.show()

# %%
S_q_rod = Sk.S_rod(q,1)

chain_rod = WLChain(N_backbone,N_backbone*1e8,lambda_backbone)
chain_rod.d_exc = chain_rod.a*0.1
chain_rod.apply_SA = 0

def sample_S_q_rod(n_sample,chain_func,p):
    S_q = np.zeros_like(q)
    for i in tqdm(range(n_sample)):
        chain_func.chain()
        chain_func.scatter_direct(q,n_merge=1,p_sub=p)
        S_q += chain_func.S_q
        
    return(S_q)

S_q_rod_sample = sample_S_q_rod(n_sample,chain_rod,0.025)
S_q_rod_MC = S_q_rod_sample/n_sample
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 50/50 [01:26<00:00,  1.73s/it]

# %%
plt.close('all')
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot()
ax.plot(q,S_q_rod,'-k')
ax.plot(q,S_q_rod_MC,'-r')
ax.set_xscale('log')
ax.set_yscale('log')

plt.show()
